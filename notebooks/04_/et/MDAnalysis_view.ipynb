# %% [markdown]
# Just to view the molecule

# %%
import MDAnalysis as mda
import nglview as nv

# !jupyter-nbextension enable nglview --py --sys-prefix
# Out:
# /bin/bash: line 1: jupyter-nbextension: command not found
# /home/errol-laptop/miniconda3/envs/kmc/lib/python3.13/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
u = mda.Universe('molecule_100.gro')

# Create viewer
view = nv.show_mdanalysis(u)
view.clear_representations()
view.add_representation("ball+stick")
view.center()
view
# Out:
# NGLWidget()
